# %%
# import the packages
# import the library package 
import pandas 
import numpy

import matplotlib.pyplot as plt 

from sklearn.feature_selection import RFE 
from sklearn.ensemble import ExtraTreesRegressor,RandomForestRegressor 
from sklearn.metrics import mean_absolute_error,explained_variance_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import cross_val_score

# create your MLP in keras 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.wrappers.scikit_learn import KerasRegressor 
from sklearn.model_selection import KFold
from keras.optimizers import Adam

# fix random seed for reproducibility 
seed = 7
numpy.random.seed(seed)

# %%
# load the dataset 
gas = pandas.read_csv("gas_turbines.csv",delimiter=',')
gas
# Out:
#            AT      AP      AH    AFDP  ...     TEY     CDP      CO     NOX
# 0      6.8594  1007.9  96.799  3.5000  ...  114.70  10.605  3.1547  82.722
# 1      6.7850  1008.4  97.118  3.4998  ...  114.72  10.598  3.2363  82.776
# 2      6.8977  1008.8  95.939  3.4824  ...  114.71  10.601  3.2012  82.468
# 3      7.0569  1009.2  95.249  3.4805  ...  114.72  10.606  3.1923  82.670
# 4      7.3978  1009.7  95.150  3.4976  ...  114.72  10.612  3.2484  82.311
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  ...  111.61  10.400  4.5186  79.559
# 15035  7.8879  1005.9  99.093  3.5059  ...  111.78  10.433  4.8470  79.917
# 15036  7.2647  1006.3  99.496  3.4770  ...  110.19  10.483  7.9632  90.912
# 15037  7.0060  1006.8  99.008  3.4486  ...  110.74  10.533  6.2494  93.227
# 15038  6.9279  1007.2  97.533  3.4275  ...  111.58  10.583  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
gas.describe()
# Out:
#                  AT           AP  ...            CO           NOX
# count  15039.000000  15039.00000  ...  15039.000000  15039.000000
# mean      17.764381   1013.19924  ...      1.972499     68.190934
# std        7.574323      6.41076  ...      2.222206     10.470586
# min        0.522300    985.85000  ...      0.000388     27.765000
# 25%       11.408000   1008.90000  ...      0.858055     61.303500
# 50%       18.186000   1012.80000  ...      1.390200     66.601000
# 75%       23.862500   1016.90000  ...      2.160400     73.935500
# max       34.929000   1034.20000  ...     44.103000    119.890000
#
# [8 rows x 11 columns]

# %%
gas.head()
# Out:
#        AT      AP      AH    AFDP  ...     TEY     CDP      CO     NOX
# 0  6.8594  1007.9  96.799  3.5000  ...  114.70  10.605  3.1547  82.722
# 1  6.7850  1008.4  97.118  3.4998  ...  114.72  10.598  3.2363  82.776
# 2  6.8977  1008.8  95.939  3.4824  ...  114.71  10.601  3.2012  82.468
# 3  7.0569  1009.2  95.249  3.4805  ...  114.72  10.606  3.1923  82.670
# 4  7.3978  1009.7  95.150  3.4976  ...  114.72  10.612  3.2484  82.311
#
# [5 rows x 11 columns]

# %%
gas.shape
# Out:
# (15039, 11)

# %%
gas.dtypes # datatypes
# Out:
# AT      float64
# AP      float64
# AH      float64
# AFDP    float64
# GTEP    float64
# TIT     float64
# TAT     float64
# TEY     float64
# CDP     float64
# CO      float64
# NOX     float64
# dtype: object

# %%
print("correlation:",gas.corr(method='pearson'))
# Out:
# correlation:             AT        AP        AH  ...       CDP        CO       NOX
# AT    1.000000 -0.412953 -0.549432  ... -0.100705 -0.088588 -0.600006
# AP   -0.412953  1.000000  0.042573  ...  0.131198  0.041614  0.256744
# AH   -0.549432  0.042573  1.000000  ... -0.182010  0.165505  0.143061
# AFDP -0.099333  0.040318 -0.119249  ...  0.727152 -0.334207 -0.037299
# GTEP -0.049103  0.078575 -0.202784  ...  0.993784 -0.508259 -0.208496
# TIT   0.093067  0.029650 -0.247781  ...  0.887238 -0.688272 -0.231636
# TAT   0.338569 -0.223479  0.010859  ... -0.744740  0.063404  0.009888
# TEY  -0.207495  0.146939 -0.110272  ...  0.988473 -0.541751 -0.102631
# CDP  -0.100705  0.131198 -0.182010  ...  1.000000 -0.520783 -0.169103
# CO   -0.088588  0.041614  0.165505  ... -0.520783  1.000000  0.316743
# NOX  -0.600006  0.256744  0.143061  ... -0.169103  0.316743  1.000000
#
# [11 rows x 11 columns]

# %%
# split into input and output values 
x=gas.iloc[:,0:10]
y=gas.iloc[:,10]

# %%
print(x)
print(y)
# Out:
#            AT      AP      AH    AFDP  ...     TAT     TEY     CDP      CO
# 0      6.8594  1007.9  96.799  3.5000  ...  550.00  114.70  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  ...  550.00  114.72  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  ...  549.87  114.71  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  ...  549.99  114.72  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  ...  549.98  114.72  10.612  3.2484
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  ...  546.21  111.61  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  ...  543.22  111.78  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  ...  537.32  110.19  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  ...  541.24  110.74  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  ...  545.85  111.58  10.583  4.9816
#
# [15039 rows x 10 columns]
# 0        82.722
# 1        82.776
# 2        82.468
# 3        82.670
# 4        82.311
#           ...
# 15034    79.559
# 15035    79.917
# 15036    90.912
# 15037    93.227
# 15038    92.498
# Name: NOX, Length: 15039, dtype: float64

# %%
# feature selection 
model = ExtraTreesRegressor()
rfe = RFE(model,3)
model1 = rfe.fit(x,y)

print("Numbers of features:",model1.n_features_)
print("Selected features:",model1.support_)
print("Feature ranking :",model1.ranking_)
# Out:
# Numbers of features: 3
# Selected features: [ True False False False False  True False  True False False]
# Feature ranking : [1 8 5 7 2 1 6 1 4 3]

# %%
 # define model 
def create_model():
  model = Sequential()
  model.add(Dense(12,input_dim = 12,kernel_initializer='uniform',activation='relu'))
  model.add(Dense(6,kernel_initializer='uniform',activation='relu'))
  model.add(Dense(1,kernel_initializer='uniform',activation='relu'))

  adam=Adam(learning_rate=0.1)

  # compile model 
  model.compile (loss='mean_squared_error',optimizer = adam)
  return model

# %%
# evaluate the model 
estimator = KerasRegressor(build_fn=create_model,epochs=600,batch_size=5,verbose = 0)
kfold = KFold(n_splits=10,random_state=seed)
results = cross_val_score(estimator,x,y,cv=kfold)
print("results")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_240 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_241 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_242 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_243 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_244 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_245 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_246 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_247 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_248 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (5, 10)
#
#
#   FitFailedWarning)
# results
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:770 train_step  *
#         y_pred = self(x, training=True)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:989 __call__  *
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:248 assert_input_compatibility  *
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_249 is incompatible with the layer: expected axis -1 of input shape to have value 12 but received input with shape (None, 10)
#
#
#   FitFailedWarning)
